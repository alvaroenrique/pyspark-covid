# %%
import numpy as np
import pandas as pd

import numpy as np
import pandas as pd

df = pd.read_excel('SINADEF_DATOS_ABIERTOS_21072020.xlsx',
                   index_col=0, sheet_name="Tabla_SINADEF", skiprows=3)

df.head()
# Out:
#    TIPO SEGURO       SEXO EDAD TIEMPO EDAD ESTADO CIVIL  \
# Nº
# 1          SIS  MASCULINO   43        AÑOS      SOLTERO
# 2     IGNORADO  MASCULINO   91        AÑOS       CASADO
# 3      ESSALUD  MASCULINO   80        AÑOS       CASADO
# 4     IGNORADO  MASCULINO   24        AÑOS      SOLTERO
# 5     IGNORADO  MASCULINO   60        AÑOS      SOLTERO
#
#        NIVEL DE INSTRUCCIÓN COD# UBIGEO DOMICILIO PAIS DOMICILIO  \
# Nº
# 1   SUPERIOR NO UNIV. COMP.    92-33-24-01-01-000           PERU
# 2                  IGNORADO    92-33-06-01-06-000           PERU
# 3                  IGNORADO    92-33-12-01-01-000           PERU
# 4                  IGNORADO    92-33-06-02-01-000           PERU
# 5       SECUNDARIA COMPLETA    92-33-06-01-01-000           PERU
#
#    DEPARTAMENTO DOMICILIO PROVINCIA DOMICILIO  ...  \
# Nº                                             ...
# 1                  CALLAO              CALLAO  ...
# 2               CAJAMARCA           CAJAMARCA  ...
# ...

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b666bf274d0a> in <module>
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df['AÑO'].value_counts()
# Out:
# 2019    114944
# 2018    112812
# 2020    109375
# 2017     98975
# Name: AÑO, dtype: int64

# %%
df['DEBIDO A (CAUSA A)'].value_counts()
# Out:
# INSUFICIENCIA RESPIRATORIA           60179
# INSUFICIENCIA RESPIRATORIA AGUDA     51747
# FALLA MULTIORGANICA                  17964
# SHOCK SEPTICO                        10595
# SEPSIS                               10199
#                                      ...
# MUERTE SIN ASISTTENCIA                   1
# INSUFICIENCIA RE3SPIRATORIA AGUDA        1
# LINFOMA DIFUSO DE LINFOCITOS T           1
# SEPTICEMIA DEL RECIEN NACIDO             1
# TRUMATISMO INTRACRANEAL                  1
# Name: DEBIDO A (CAUSA A), Length: 41611, dtype: int64

# %%
len(df[df['DEBIDO A (CAUSA A)'].str.contains('COVID')])
# Out:
# 3112
